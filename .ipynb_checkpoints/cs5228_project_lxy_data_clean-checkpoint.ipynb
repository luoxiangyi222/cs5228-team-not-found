# %% [markdown]
# # CS5228 Project - Team not found
#
# # Data cleaning

# %%
# import packages

import numpy as np
import pandas as pd
from src.utils import *

# %% [markdown]
# ## Load Data

# %%
path = "./"

original_train_df = pd.read_csv(path + "data/train.csv")
original_test_df = pd.read_csv(path + "data/test.csv")

# %%
# duplicate dataset

train_df = original_train_df.copy()
test_df = original_test_df.copy()

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (26048, 23)
# (7500, 22)

# %%
train_df.head()
# Out:
#    listing_id                  name             street         type  \
# 0     6998418              seascape       57 cove way   condominium
# 1     2046604             la maison  10 moulmein rise     apartment
# 2     7563513                  viva    2 suffolk walk   condominium
# 3     3071445       urban treasures   205 jalan eunos   condominium
# 4     9667539  infini at east coast    east coast road    apartment
#
#          model market_segment type_of_area bedrooms  bathrooms  district  ...  \
# 0  condominium            ocr       strata        3        4.0         4  ...
# 1    apartment            ocr       strata        3        3.0        11  ...
# 2  condominium            ocr       strata        4        3.0        11  ...
# 3  condominium            ocr       strata        3        2.0        14  ...
# 4    apartment            ocr       strata        3        3.0        15  ...
#
#         lat         lng              tenure  built_year  no_of_units  \
# 0  1.239337  103.837487  leasehold/99 years      2011.0        151.0
# 1  1.319533  103.847030            freehold      1999.0         24.0
# 2  1.315656  103.844445            freehold      2012.0        235.0
# 3  1.329367  103.905791            freehold         NaN        237.0
# 4  1.309176  103.911352            freehold         NaN         36.0
#
#   area_size   eco_category  accessibility  date_listed      price
# 0    2336.0  uncategorized        guarded   2021-05-04  5390000.0
# 1    1259.0  uncategorized        guarded   2021-05-07  2310000.0
# 2    1959.0  uncategorized        guarded   2021-06-30  5279500.0
# 3     883.0  uncategorized        guarded   2022-01-02  1843600.0
# 4    1066.0  uncategorized        guarded   2021-12-24  2262700.0
#
# [5 rows x 23 columns]

# %%
print(train_df.dtypes)
# Out:
# listing_id          int64
# name               object
# street             object
# type               object
# model              object
# market_segment     object
# type_of_area       object
# bedrooms           object
# bathrooms         float64
# district            int64
# region             object
# planning_area      object
# subszone           object
# lat               float64
# lng               float64
# tenure             object
# built_year        float64
# no_of_units       float64
# area_size         float64
# eco_category       object
# accessibility      object
# date_listed        object
# price             float64
# dtype: object

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Check null value

# %%
# combine train and test

train_test_X = pd.concat([train_df.iloc[:,:-1], test_df], axis=0)

print(train_df.shape)
print(train_test_X.shape)

print(compute_null_count(original_train_df))
print(compute_null_count(original_test_df))
# Out:
# (26048, 23)
# (33548, 22)
# listing_id            0
# name                  0
# street                0
# type                  0
# model              1280
# market_segment        0
# type_of_area          0
# bedrooms            404
# bathrooms          1236
# district              0
# region                0
# planning_area         0
# subszone              0
# lat                   0
# lng                   0
# tenure              287
# built_year        10043
# no_of_units        1042
# area_size             2
# eco_category          0
# accessibility         0
# date_listed           0
# price                 0
# dtype: int64
# listing_id           0
# name                 0
# street               0
# type                 0
# model              388
# market_segment       0
# type_of_area         0
# bedrooms           118
# bathrooms          337
# district             0
# region               0
# planning_area        0
# subszone             0
# lat                  0
# lng                  0
# tenure              85
# built_year        2875
# no_of_units        326
# area_size            0
# eco_category         0
# accessibility        0
# date_listed          0
# dtype: int64

# %% [markdown]
# #### type
#
# conflicts:
#
# **type:aprt; model:condo**  =>  align with type
#
# **type:condo; model:aprt** => google search

# %%
########## train ################

type_df = train_df
type_df = type_df[type_df["type"] != type_df["model"]]
type_df_a = type_df[type_df["model"] == "condominium"]


display(type_df_a.sort_values("name"))

# by checking property in the same name, these conflicts should be aligned with type
train_df.loc[
    (train_df["type"] == "apartment") & (train_df["model"] == "condominium"), "model"
] = "apartment"
# Out:
#        listing_id                      name                     street  \
# 2372      3357452                76 shenton                76 shenton
# 13370     9500389     affinity at serangoon  18 affinity at serangoon
# 12431     7417446     affinity at serangoon  18 affinity at serangoon
# 541       4358147                casa merah             56 casa merah
# 8974      1413080          eastwood regency       40 eastwood regency
# 23093     4361105  fourth avenue residences   fourth avenue residences
# 23854     6643220                      icon          10 gopeng street
# 1692      8514400                  la brisa               50 la brisa
# 1036      8577817            midtown modern             midtown modern
# 6916      1863369        nottinghill suites         29a toh tuck road
# 14911     2829307            one pearl bank              1 pearl bank
# 21399     5843211            one pearl bank              1 pearl bank
# 11282     7063153               parc sophia              10 adis road
# 15028     9451493           riveria gardens         river valley grove
# 2403      5874463             scotts square           8 scotts square
# 1411      2657190         sloane residences          sloane residences
# 3843      5738424           spottiswoode 18        18 spottiswoode 18
# 25554     7350004         suites at orchard          suites at orchard
# 1690      6681487        the clement canopy     18 the clement canopy
# 5363      2876349                 the clift                  the clift
# 19326     2678750                 the clift                  the clift
# 3567      2173407       the poiz residences        the poiz residences
# 24326     9263885     the sail @ marina bay   6 the sail @ marina bay
# 2076      6794895               the tennery                the tennery
#
#             type        model market_segment type_of_area bedrooms  bathrooms  \
# 2372   apartment  condominium            ocr       strata        1        1.0
# 13370  apartment  condominium            ocr       strata        1        1.0
# 12431  apartment  condominium            ocr       strata        1        1.0
# 541    apartment  condominium            ocr       strata        3        NaN
# 8974   apartment  condominium            ocr       strata        1        1.0
# 23093  apartment  condominium            ocr       strata        4        3.0
# 23854  apartment  condominium            ocr       strata        1        1.0
# 1692   apartment  condominium            ocr       strata        2        2.0
# 1036   apartment  condominium            ocr       strata        4        3.0
# 6916   apartment  condominium            ocr       strata        1        2.0
# 14911  apartment  condominium            ocr       strata        2        2.0
# 21399  apartment  condominium            ocr       strata        1        1.0
# 11282  apartment  condominium            ocr       strata        2        1.0
# 15028  apartment  condominium            ocr       strata        2        2.0
# 2403   apartment  condominium            ocr       strata        2        2.0
# 1411   apartment  condominium            ocr       strata        4        3.0
# 3843   apartment  condominium            ocr       strata        1        1.0
# 25554  apartment  condominium            ocr       strata        1        1.0
# 1690   apartment  condominium            ocr       strata      3+1        NaN
# 5363   apartment  condominium            ocr       strata        1        1.0
# 19326  apartment  condominium            ocr       strata        1        2.0
# 3567   apartment  condominium            ocr       strata      NaN        1.0
# 24326  apartment  condominium            ocr       strata        2        2.0
# 2076   apartment  condominium            ocr       strata        2        2.0
#
#        district  ...       lat         lng                    tenure  \
# 2372          2  ...  1.273477  103.845553        leasehold/99 years
# 13370        19  ...  1.365660  103.873225        leasehold/99 years
# 12431        19  ...  1.365660  103.873225        leasehold/99 years
# 541          16  ...  1.329576  103.944985        leasehold/99 years
# 8974         16  ...  1.321127  103.957521                  freehold
# 23093        10  ...  1.329713  103.796996        leasehold/99 years
# 23854         2  ...  1.275170  103.844496        leasehold/99 years
# 1692         14  ...  1.311904  103.885369                  freehold
# 1036          7  ...  1.298505  103.857088        leasehold/99 years
# 6916         21  ...  1.338854  103.769183                  freehold
# 14911         3  ...  1.282961  103.839815        leasehold/99 years
# 21399         3  ...  1.282961  103.839815        leasehold/99 years
# 11282         9  ...  1.301418  103.847570                  freehold
# 15028         9  ...  1.297282  103.834691                  freehold
# 2403          9  ...  1.305799  103.833075                  freehold
# 1411         10  ...  1.315689  103.832318                  freehold
# 3843          2  ...  1.275595  103.837560                  freehold
# 25554         9  ...  1.300420  103.845958        leasehold/99 years
# 1690          5  ...  1.306676  103.768537  99 years from 09/03/2016
# 5363          1  ...  1.279400  103.847330        leasehold/99 years
# 19326         1  ...  1.279400  103.847330        leasehold/99 years
# 3567         13  ...  1.332027  103.868659        leasehold/99 years
# 24326         1  ...  1.280769  103.852659        leasehold/99 years
# 2076         23  ...  1.379727  103.760191        leasehold/99 years
#
#        built_year  no_of_units area_size   eco_category  accessibility  \
# 2372       2014.0        202.0     624.0  uncategorized        guarded
# 13370         NaN       1052.0     474.0  uncategorized        guarded
# 12431         NaN       1052.0     474.0  uncategorized        guarded
# 541        2009.0        556.0    1227.0  uncategorized        guarded
# 8974       2010.0         75.0     517.0  uncategorized        guarded
# 23093         NaN        476.0    1485.0  uncategorized        guarded
# 23854      2007.0        646.0     570.0  uncategorized        guarded
# 1692       2012.0         84.0     624.0  uncategorized        guarded
# 1036          NaN        558.0    1808.0  uncategorized        guarded
# 6916       2014.0        124.0     560.0  uncategorized        guarded
# 14911         NaN        774.0     700.0  uncategorized        guarded
# 21399         NaN        774.0     527.0  uncategorized        guarded
# 11282      2011.0        152.0     732.0  uncategorized        guarded
# 15028      2010.0         49.0     969.0  uncategorized        guarded
# 2403       2011.0        338.0     947.0  uncategorized        guarded
# 1411          NaN         52.0    1496.0  uncategorized        guarded
# 3843       2014.0        251.0     893.0  uncategorized        guarded
# 25554      2014.0        118.0     560.0  uncategorized        guarded
# 1690       2019.0        505.0    1314.0  uncategorized        guarded
# 5363       2011.0        312.0     527.0  uncategorized        guarded
# 19326      2011.0        312.0     527.0  uncategorized        guarded
# 3567       2018.0        731.0     441.0  uncategorized        guarded
# 24326      2008.0       1111.0     861.0  uncategorized        guarded
# 2076       2014.0        338.0     861.0  uncategorized        guarded
#
#        date_listed      price
# 2372    2021-12-31  1430000.0
# 13370   2022-01-04   847000.0
# 12431   2022-01-02   847000.0
# 541     2021-12-01  1760000.0
# 8974    2021-12-30   977800.0
# 23093   2021-12-08  3884100.0
# 23854   2021-05-29  1320000.0
# 1692    2021-12-03   968000.0
# 1036    2022-01-02  5337200.0
# 6916    2021-11-19   935000.0
# 14911   2021-12-13  1981100.0
# 21399   2021-12-11  1445400.0
# 11282   2021-12-31  1485000.0
# 15028   2021-12-29  2560800.0
# 2403    2021-12-31  4180000.0
# 1411    2021-12-08  4532300.0
# 3843    2021-12-30  1870000.0
# 25554   2021-12-31  1375000.0
# 1690    2021-12-08  2200000.0
# 5363    2021-12-11  1237500.0
# 19326   2021-10-24  1237500.0
# 3567    2022-01-05   924000.0
# 24326   2021-12-17  1870000.0
# 2076    2021-09-28  1232000.0
#
# [24 rows x 23 columns]

# %%
# type_df = train_df
# type_df = type_df[type_df['type'] != type_df['model']]
# type_df_a = type_df[type_df['model'] == 'condominium']
# display(type_df_a.sort_values('name'))

# %%
type_df_b = type_df[type_df["model"] == "apartment"]
display(type_df_b)
# by see other property in spottiswoode residences, it is condo
train_df.loc[(train_df["name"] == "spottiswoode residences"), "model"] = "condominium"
# by Google search , tan quee lan street is apartment.
train_df.loc[(train_df["name"] == "tan quee lan street"), "type"] = "apartment"
# Out:
#        listing_id                     name                      street  \
# 404       8117494  spottiswoode residences  48 spottiswoode park road
# 20095     3352937      tan quee lan street         tan quee lan street
#
#               type      model market_segment type_of_area bedrooms  bathrooms  \
# 404    condominium  apartment            ocr       strata        2        2.0
# 20095  condominium  apartment            ocr       strata        1        1.0
#
#        district  ...       lat         lng              tenure  built_year  \
# 404           2  ...  1.275271  103.836832            freehold      2013.0
# 20095         7  ...  1.298002  103.856935  leasehold/99 years         NaN
#
#        no_of_units area_size   eco_category  accessibility  date_listed  \
# 404          351.0     936.0  uncategorized        guarded   2022-01-05
# 20095          NaN     474.0  uncategorized        guarded   2021-10-20
#
#            price
# 404    2310000.0
# 20095  1415700.0
#
# [2 rows x 23 columns]

# %%
# type_df = train_df
# type_df = type_df[type_df['type'] != type_df['model']]
# type_df_b = type_df[type_df['model'] == 'apartment']
# type_df_b

# %%
########## test ################

type_df = test_df
type_df = type_df[type_df["type"] != type_df["model"]]
type_df_a = type_df[type_df["model"] == "condominium"]
display(type_df_a.sort_values("name"))


test_df.loc[test_df["name"] == "the poiz residences", "model"] = "apartment"
# Out:
#       listing_id                 name                     street       type  \
# 4038     7642307  the poiz residences  12 meyappa chettiar road   apartment
#
#             model market_segment type_of_area bedrooms  bathrooms  district  \
# 4038  condominium            ocr       strata        2        NaN        13
#
#       ...      subszone       lat         lng              tenure  built_year  \
# 4038  ...  potong pasir  1.331545  103.866996  leasehold/99 years      2019.0
#
#      no_of_units  area_size   eco_category  accessibility date_listed
# 4038       731.0      753.0  uncategorized        guarded  2022-01-03
#
# [1 rows x 22 columns]

# %%
# type_df = test_df
# type_df = type_df[type_df['type'] != type_df['model']]
# type_df_a = type_df[type_df['model'] == 'condominium']
# display(type_df_a.sort_values('name'))

# %%
type_df_b = type_df[type_df["model"] == "apartment"]
display(type_df_b.sort_values("name"))


test_df.loc[test_df["name"] == "haus on handy", "model"] = "condominium"
# Out:
#      listing_id           name             street         type      model  \
# 993     7474544  haus on handy  30 haus on handy   condominium  apartment
#
#     market_segment type_of_area bedrooms  bathrooms  district  ...  \
# 993            ocr       strata        1        NaN         9  ...
#
#         subszone       lat        lng              tenure  built_year  \
# 993  dhoby ghaut  1.300136  103.84675  leasehold/99 years         NaN
#
#     no_of_units  area_size   eco_category  accessibility date_listed
# 993       188.0      452.0  uncategorized        guarded  2022-01-02
#
# [1 rows x 22 columns]

# %%
# type_df = test_df
# type_df = type_df[type_df['type'] != type_df['model']]
# type_df_b = type_df[type_df['model'] == 'apartment']
# display(type_df_b.sort_values('name'))

# %% [markdown]
# #### model

# %%
########## train ################

print(compute_null_count(train_df, ["model"]))

# fill null by name
train_df = fill_missing_value_by_group_neighbor(train_df, "model", "name")
print(compute_null_count(train_df, ["model"]))

# fill null by street
train_df = fill_missing_value_by_group_neighbor(train_df, "model", "street")
print(compute_null_count(train_df, ["model"]))


# by type
train_df["model"] = train_df["model"].fillna(train_df["type"])
print(compute_null_count(train_df, ["model"]))
# Out:
# model    1279
# dtype: int64
# model    24
# dtype: int64
# model    15
# dtype: int64
# model    0
# dtype: int64

# %%
# merge
final_groups = ['apartment', 'condominium', 'executive condominium','landed']
landed = ['townhouse', 'strata terrace', 'duplex']

train_df.loc[train_df['model'].isin(landed), 'model'] = 'landed'

train_df.loc[~train_df['model'].isin(final_groups), 'model'] = train_df['type']

train_df[['model']].value_counts()
# Out:
# model
# apartment                13864
# condominium              11475
# executive condominium      654
# landed                      55
# dtype: int64

# %%
########## test ################

N, d = test_df.shape
train_test_X = pd.concat([train_df.iloc[:, :-1], test_df], axis=0).copy().reset_index(drop=True)

print(train_df.shape)
print(train_test_X.shape)



print(compute_null_count(test_df, ["model"]))

# fill null by name
train_test_X = fill_missing_value_by_group_neighbor(train_test_X, "model", "name") 
print(compute_null_count(train_test_X, ["model"]))

# # by street
train_test_X = fill_missing_value_by_group_neighbor(train_test_X, "model", "street")
print(compute_null_count(train_test_X, ["model"]))


test_df = train_test_X.iloc[-N:, :].copy()




# by type
test_df["model"] = test_df["model"].fillna(test_df["type"])
print(compute_null_count(test_df, ["model"]))


print(test_df.shape)
# Out:
# (26048, 23)
# (33548, 22)
# model    387
# dtype: int64
# model    3
# dtype: int64
# model    2
# dtype: int64
# model    0
# dtype: int64
# (7500, 22)

# %%
# merge
final_groups = ['apartment', 'condominium', 'executive condominium','landed']
landed = ['townhouse', 'strata terrace', 'duplex']

test_df.loc[test_df['model'].isin(landed), 'model'] = 'landed'

test_df.loc[~test_df['model'].isin(final_groups), 'model'] = test_df['type']

test_df[['model']].value_counts()
# Out:
# model
# apartment                3964
# condominium              3334
# executive condominium     183
# landed                     19
# dtype: int64

# %% [markdown]
# #### area size

# %%
# area_size

########## train ################


# fill null by bed rooms
train_df = fill_missing_value_by_neighbor(train_df, "area_size", "bedrooms")
print(compute_null_count(train_df, 'area_size'))
# Out:
# 0

# %%
# test code

df = pd.DataFrame(
    [["a", 6.2, 1], ["b", 0.0, None], ["b", 1.5, 6], ["c", 1.6, 7], ["a", 2.0, None]]
)

df.columns = ["k", "g", "value"]

display(df)

# df = fill_missing_value_by_group_neighbor(df, 'value', 'k')

df["value"] = df["value"].fillna(df["k"])

display(df)
# Out:
#    k    g  value
# 0  a  6.2    1.0
# 1  b  0.0    NaN
# 2  b  1.5    6.0
# 3  c  1.6    7.0
# 4  a  2.0    NaN
#    k    g value
# 0  a  6.2   1.0
# 1  b  0.0     b
# 2  b  1.5   6.0
# 3  c  1.6   7.0
# 4  a  2.0     a

# %% [markdown]
# #### bedroom

# %%
########## train ################

# break into bedrooms and additional rooms
print(compute_null_count(train_df, ["bedrooms"]))

# fill null according to area size
train_df = fill_missing_value_by_neighbor(train_df, "bedrooms", "area_size")

print(compute_null_count(train_df, ["bedrooms"]))
# Out:
# bedrooms    404
# dtype: int64
# bedrooms    0
# dtype: int64

# %%
########## test ################

N, d = test_df.shape
train_test_X = pd.concat([train_df.iloc[:, :-1], test_df], axis=0).copy().reset_index(drop=True)

print(train_df.shape)
print(train_test_X.shape)

print(compute_null_count(test_df, ["bedrooms"]))
# fill null according to area size
test_df = fill_missing_value_by_neighbor(train_test_X, "bedrooms", "area_size").iloc[-N:, :].copy()
print(compute_null_count(test_df, ['bedrooms']))


print(test_df.shape)
# Out:
# (26048, 23)
# (33548, 22)
# bedrooms    118
# dtype: int64
# bedrooms    0
# dtype: int64
# (7500, 22)

# %%
# split

########## train ################
# # split to two columns
train_df[["bedrooms", "additional_rooms"]] = (
    train_df["bedrooms"].str.split("+", expand=True).fillna(0)
)

train_df[["bedrooms", "additional_rooms"]] = train_df[
    ["bedrooms", "additional_rooms"]
].astype("int")

print(compute_null_count(train_df, ["bedrooms", "additional_rooms"]))


train_df = train_df[np.append(train_df.columns[:-2], ['additional_rooms', 'price'])]
# Out:
# bedrooms            0
# additional_rooms    0
# dtype: int64

# %%
########## test ################
# split to to columns

test_df[["bedrooms", "additional_rooms"]] = (
    test_df["bedrooms"].str.split("+", expand=True).fillna(0)
)


# # convert empty string to null
test_df.loc[test_df["additional_rooms"] == '', 'additional_rooms'] = np.nan 


# fill null by 0
test_df[["bedrooms", "additional_rooms"]] = test_df[
    ["bedrooms", "additional_rooms"]
].fillna(0)

# convert type to int
test_df[["bedrooms", "additional_rooms"]] = test_df[
    ["bedrooms", "additional_rooms"]
].astype("int")

# print()
print(compute_null_count(test_df, ["bedrooms", "additional_rooms"]))
# Out:
# bedrooms            0
# additional_rooms    0
# dtype: int64

# %% [markdown]
# #### bathroom

# %%
########## train ################
print(compute_null_count(train_df, ["bathrooms"]))

# fill null by bedrooms
train_df = fill_missing_value_by_neighbor(train_df, "bathrooms", "bedrooms")
print(compute_null_count(train_df, ["bathrooms"]))
# Out:
# bathrooms    1236
# dtype: int64
# bathrooms    0
# dtype: int64

# %%
########## test ################
print(compute_null_count(test_df, ["bathrooms"]))

N, d = test_df.shape
train_test_X = pd.concat([train_df.iloc[:, :-1], test_df], axis=0).copy().reset_index(drop=True)

print(train_df.shape)
print(train_test_X.shape)


test_df = fill_missing_value_by_neighbor(train_test_X, "bathrooms", "bedrooms").iloc[-N:, :].copy()
print(compute_null_count(test_df, ["bathrooms"]))


print(test_df.shape)
# Out:
# bathrooms    337
# dtype: int64
# (26048, 24)
# (33548, 23)
# bathrooms    0
# dtype: int64
# (7500, 23)

# %% [markdown]
# #### tenure
#
# https://www.propertyguru.com.sg/property-guides/singapore-freehold-vs-leasehold-which-is-better-9520

# %%
########## train ################

# fill null by name
print(compute_null_count(train_df, ["tenure"]))
train_df = fill_missing_value_by_group_neighbor(train_df, "tenure", "name")
print(compute_null_count(train_df, ["tenure"]))

# fill null by street
train_df = fill_missing_value_by_group_neighbor(train_df, "tenure", "street")
print(compute_null_count(train_df, ["tenure"]))

# by mode
train_df["tenure"] = train_df["tenure"].fillna(train_df[["tenure"]].mode().iloc[0, 0])
print(compute_null_count(train_df, ["tenure"]))
# Out:
# tenure    287
# dtype: int64
# tenure    72
# dtype: int64
# tenure    21
# dtype: int64
# tenure    0
# dtype: int64

# %%
########## test ################

N, d = test_df.shape
train_test_X = pd.concat([train_df.iloc[:, :-1], test_df], axis=0).copy().reset_index(drop=True)



# fill null by name
print(compute_null_count(test_df, ["tenure"]))
# test_df = fill_missing_value_by_group_neighbor(test_df, "tenure", "name")

train_test_X = fill_missing_value_by_group_neighbor(train_test_X, "tenure", "name") 
print(compute_null_count(train_test_X, ["tenure"]))

# # by street
train_test_X = fill_missing_value_by_group_neighbor(train_test_X, "tenure", "street")
print(compute_null_count(train_test_X, ["tenure"]))

# by mode
train_test_X['tenure'] = train_test_X["tenure"].fillna(
    train_test_X["tenure"].mode().iloc[0]
)


test_df = train_test_X.iloc[-N:, :].copy()
print(compute_null_count(test_df, ["tenure"]))
# Out:
# tenure    85
# dtype: int64
# tenure    15
# dtype: int64
# tenure    11
# dtype: int64
# tenure    0
# dtype: int64

# %%
########## train ################
# change freehold to 999 years
train_df.loc[train_df["tenure"] == "freehold", "tenure"] = "999 years"

# get year number
freehold = train_df["tenure"].str.extract("(\d+)").astype("int")

freehold[freehold <= 99] = 0
freehold[freehold > 99] = 1

train_df = train_df.rename(columns={"tenure": "freehold"})
train_df["freehold"] = freehold

print(compute_null_count(train_df, ["freehold"]))

train_df['freehold'].value_counts()
# Out:
# freehold    0
# dtype: int64
# 0    15557
# 1    10491
# Name: freehold, dtype: int64

# %%
########## test ################
# change freehold to 999

test_df.loc[test_df["tenure"] == "freehold", "tenure"] = "999 years"

freehold = test_df["tenure"].str.extract("(\d+)").astype("int")


freehold[freehold <= 99] = 0
freehold[freehold > 99] = 1

test_df = test_df.rename(columns={"tenure": "freehold"})
test_df["freehold"] = freehold


test_df[["freehold"]].value_counts()
# Out:
# freehold
# 0           4379
# 1           3121
# dtype: int64

# %% [markdown]
# #### built year

# %%
########## train ################

# fill null
print(compute_null_count(train_df, ["built_year"]))

# by name
train_df = fill_missing_value_by_group_neighbor(train_df, "built_year", "name")
print(compute_null_count(train_df, ["built_year"]))

# by street
train_df = fill_missing_value_by_group_neighbor(train_df, "built_year", "street")
print(compute_null_count(train_df, ["built_year"]))

# filled by 'unknown'
train_df["built_year"] = train_df["built_year"].fillna(-1)
print(compute_null_count(train_df, ["built_year"]))
# Out:
# built_year    10043
# dtype: int64
# built_year    2684
# dtype: int64
# built_year    1360
# dtype: int64
# built_year    0
# dtype: int64

# %%
########## test ################

N, d = test_df.shape
train_test_X = pd.concat([train_df.iloc[:, :-1], test_df], axis=0).copy().reset_index(drop=True)



# fill null by name
print(compute_null_count(test_df, ["built_year"]))

# by name
train_test_X = fill_missing_value_by_group_neighbor(train_test_X, "built_year", "name") 
print(compute_null_count(train_test_X, ["built_year"]))

# by street
train_test_X = fill_missing_value_by_group_neighbor(train_test_X, "built_year", "street") 
print(compute_null_count(train_test_X, ["built_year"]))


test_df = train_test_X.iloc[-N:, :].copy()

# filled by 'unknown'
test_df["built_year"] = test_df["built_year"].fillna(-1)
print(compute_null_count(test_df, ["built_year"]))
# Out:
# built_year    2875
# dtype: int64
# built_year    24
# dtype: int64
# built_year    17
# dtype: int64
# built_year    0
# dtype: int64

# %% [markdown]
# #### no_of_units

# %%
########## train ################
print(compute_null_count(train_df, ["no_of_units"]))


# by name
train_df = fill_missing_value_by_group_neighbor(train_df, "no_of_units", "name")
print(compute_null_count(train_df, ["no_of_units"]))

# by street
train_df = fill_missing_value_by_group_neighbor(train_df, "no_of_units", "street")
print(compute_null_count(train_df, ["no_of_units"]))


# by mean
train_df["no_of_units"] = train_df["no_of_units"].fillna(np.round(train_df["no_of_units"].mean(), 1))
print(compute_null_count(train_df, ["no_of_units"]))
# Out:
# no_of_units    1042
# dtype: int64
# no_of_units    1015
# dtype: int64
# no_of_units    505
# dtype: int64
# no_of_units    0
# dtype: int64

# %%
########## test ################



N, d = test_df.shape
train_test_X = pd.concat([train_df.iloc[:, :-1], test_df], axis=0).copy().reset_index(drop=True)



# fill null by name
print(compute_null_count(test_df, ["no_of_units"]))

# by name
train_test_X = fill_missing_value_by_group_neighbor(train_test_X, "no_of_units", "name") 
print(compute_null_count(train_test_X, ["no_of_units"]))

# by street
train_test_X = fill_missing_value_by_group_neighbor(train_test_X, "no_of_units", "street") 
print(compute_null_count(train_test_X, ["no_of_units"]))


test_df = train_test_X.iloc[-N:, :].copy()



# # by mean
test_df["no_of_units"] = test_df["no_of_units"].fillna(
    np.round(train_test_X["no_of_units"].mean(), 1)
)
print(compute_null_count(test_df, ["no_of_units"]))
# Out:
# no_of_units    326
# dtype: int64
# no_of_units    26
# dtype: int64
# no_of_units    18
# dtype: int64
# no_of_units    0
# dtype: int64

# %% [markdown]
# #### date_listed

# %%
train_df["date_listed"] = pd.to_datetime(train_df["date_listed"])
test_df["date_listed"] = pd.to_datetime(test_df["date_listed"])

# %%
# check null
compute_null_count(train_df)
# Out:
# listing_id          0
# name                0
# street              0
# type                0
# model               0
# market_segment      0
# type_of_area        0
# bedrooms            0
# bathrooms           0
# district            0
# region              0
# planning_area       0
# subszone            0
# lat                 0
# lng                 0
# freehold            0
# built_year          0
# no_of_units         0
# area_size           0
# eco_category        0
# accessibility       0
# date_listed         0
# additional_rooms    0
# price               0
# dtype: int64

# %%
compute_null_count(test_df)
# Out:
# listing_id          0
# name                0
# street              0
# type                0
# model               0
# market_segment      0
# type_of_area        0
# bedrooms            0
# bathrooms           0
# district            0
# region              0
# planning_area       0
# subszone            0
# lat                 0
# lng                 0
# freehold            0
# built_year          0
# no_of_units         0
# area_size           0
# eco_category        0
# accessibility       0
# date_listed         0
# additional_rooms    0
# dtype: int64

# %% [markdown]
# ### Check duplicates

# %%
print(np.sum(train_df["listing_id"].duplicated()))
print(np.sum(test_df["listing_id"].duplicated()))
# Out:
# 0
# 0

# %%
# apart from listing id and date listed, if all other columns are the same, the property are duplicated
identifier_cols = ['name', 'street', 'type', 'model', 'market_segment', 
                   'type_of_area', 'bedrooms', 'bathrooms', 'district', 'region', 'planning_area', 
                   'subszone', 'lat', 'lng', 'freehold', 'built_year', 'no_of_units', 'area_size', 
                   'eco_category', 'accessibility', 'additional_rooms', 'price']



# keep the last one 
train_df = train_df[~train_df.sort_values(by=['date_listed']).duplicated(subset=identifier_cols, keep='last')]
# Out:
# /var/folders/ww/lx5hky5n2j547_wgc6kgbsbc0000gn/T/ipykernel_57758/3087467821.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   train_df = train_df[~train_df.sort_values(by=['date_listed']).duplicated(subset=identifier_cols, keep='last')]

# %%
train_df
# Out:
#        listing_id                          name               street  \
# 0         6998418                      seascape         57 cove way
# 1         2046604                     la maison    10 moulmein rise
# 2         7563513                          viva      2 suffolk walk
# 3         3071445               urban treasures     205 jalan eunos
# 5         5203525  the watergardens at canberra       canberra drive
# ...           ...                           ...                  ...
# 26040     6487359      the woodleigh residences  bidadari park drive
# 26041     8394537      the vermont on cairnhill  12b cairnhill rise
# 26042     3062887                   mon jervois     39 jervois road
# 26044     3161844                   dalvey haus     101 dalvey road
# 26046     8150354                     j gateway        gateway drive
#
#               type        model market_segment type_of_area  bedrooms  \
# 0      condominium  condominium            ocr       strata         3
# 1        apartment    apartment            ocr       strata         3
# 2      condominium  condominium            ocr       strata         4
# 3      condominium  condominium            ocr       strata         3
# 5        apartment    apartment            ocr       strata         2
# ...            ...          ...            ...          ...       ...
# 26040    apartment    apartment            ocr       strata         3
# 26041    apartment    apartment            ocr       strata         1
# 26042  condominium  condominium            ocr       strata         2
# 26044  condominium  condominium            ocr       strata         3
# 26046  condominium  condominium            ocr       strata         4
#
#        bathrooms  district  ...         lng freehold built_year  no_of_units  \
# 0            4.0         4  ...  103.837487        0     2011.0        151.0
# 1            3.0        11  ...  103.847030        1     1999.0         24.0
# 2            3.0        11  ...  103.844445        1     2012.0        235.0
# 3            2.0        14  ...  103.905791        1     1930.0        237.0
# 5            1.0        27  ...  103.829104        0     1930.0        448.0
# ...          ...       ...  ...         ...      ...        ...          ...
# 26040        3.0        13  ...  103.872090        0     1960.0        667.0
# 26041        1.0         9  ...  103.838285        1     2013.0        158.0
# 26042        2.0        10  ...  103.822235        0     2016.0        109.0
# 26044        3.0        10  ...  103.825190        1     1930.0         17.0
# 26046        3.0        22  ...  103.742417        0     2016.0        738.0
#
#        area_size   eco_category  accessibility  date_listed  additional_rooms  \
# 0         2336.0  uncategorized        guarded   2021-05-04                 0
# 1         1259.0  uncategorized        guarded   2021-05-07                 0
# 2         1959.0  uncategorized        guarded   2021-06-30                 0
# 3          883.0  uncategorized        guarded   2022-01-02                 0
# 5          678.0  uncategorized        guarded   2022-01-04                 0
# ...          ...            ...            ...          ...               ...
# 26040      958.0  uncategorized        guarded   2021-12-18                 0
# 26041      526.0  uncategorized        guarded   2022-01-03                 0
# 26042      893.0  uncategorized        guarded   2021-09-29                 0
# 26044     1561.0  uncategorized        guarded   2022-01-05                 0
# 26046     1206.0  uncategorized        guarded   2021-10-23                 0
#
#            price
# 0      5390000.0
# 1      2310000.0
# 2      5279500.0
# 3      1843600.0
# 5      1131900.0
# ...          ...
# 26040  2090000.0
# 26041  1650000.0
# 26042  2090000.0
# 26044  6449300.0
# 26046  2420000.0
#
# [22417 rows x 24 columns]

# %% [markdown]
# ### Drop useless columns

# %%
print(train_df["market_segment"].value_counts())
print(train_df["type_of_area"].value_counts())
print(train_df["eco_category"].value_counts())
print(train_df["accessibility"].value_counts())
# Out:
# ocr    22417
# Name: market_segment, dtype: int64
# strata    22417
# Name: type_of_area, dtype: int64
# uncategorized    22417
# Name: eco_category, dtype: int64
# guarded    22417
# Name: accessibility, dtype: int64

# %%
print(test_df["market_segment"].value_counts())
print(test_df["type_of_area"].value_counts())
print(test_df["eco_category"].value_counts())
print(test_df["accessibility"].value_counts())
# Out:
# ocr    7500
# Name: market_segment, dtype: int64
# strata    7500
# Name: type_of_area, dtype: int64
# uncategorized    7500
# Name: eco_category, dtype: int64
# guarded    7500
# Name: accessibility, dtype: int64

# %%
# remove only one values and too many categories

to_drop_columns = [
    "market_segment",
    "type_of_area",
    "eco_category",
    "accessibility",
    "listing_id"
    
] 
# + [ "name", "street", "subszone"]

# %%
train_df = train_df.drop(columns=to_drop_columns)
train_df.shape
# Out:
# (22417, 19)

# %%
test_df = test_df.drop(columns=to_drop_columns)
test_df.shape
# Out:
# (7500, 18)

# %%
train_df.dtypes
# Out:
# name                        object
# street                      object
# type                        object
# model                       object
# bedrooms                     int64
# bathrooms                  float64
# district                     int64
# region                      object
# planning_area               object
# subszone                    object
# lat                        float64
# lng                        float64
# freehold                     int64
# built_year                 float64
# no_of_units                float64
# area_size                  float64
# date_listed         datetime64[ns]
# additional_rooms             int64
# price                      float64
# dtype: object

# %% [markdown]
# ## Data pre-processing

# %% [markdown]
# #### built_year -> since built year

# %%
from datetime import date
  
# creating the date object of today's date
todays_date = date.today()
  
# printing todays date
print("Current date: ", todays_date)
  
# fetching the current year, month and day of today
current_year = todays_date.year
current_month = todays_date.month

print(current_year)
# Out:
# Current date:  2022-04-08
# 2022

# %%
# training
train_df.loc[train_df['built_year'] > 0, 'built_year']= float(current_year) - train_df['built_year']

print(train_df[['built_year']].describe())
train_df = train_df.rename(columns={"built_year": "since_built_year"})


# testing
test_df.loc[test_df['built_year'] > 0, 'built_year']= float(current_year) - test_df['built_year']

print(test_df[['built_year']].describe())

test_df = test_df.rename(columns={"built_year": "since_built_year"})
# Out:
#          built_year
# count  22417.000000
# mean      24.142838
# std       29.652245
# min       -1.000000
# 25%        5.000000
# 50%        9.000000
# 75%       36.000000
# max      223.000000
#         built_year
# count  7500.000000
# mean     24.822000
# std      29.437414
# min      -1.000000
# 25%       6.000000
# 50%       9.000000
# 75%      37.000000
# max     223.000000

# %% [markdown]
# #### date_listed -> since list month

# %%
  


today = pd.Timestamp(todays_date)


# training

train_df['date_listed'] = today.to_period('M') - train_df['date_listed'].dt.to_period('M')

train_df['date_listed'] = train_df['date_listed'].astype('str')
train_df['date_listed'] = train_df["date_listed"].str.extract("(\d+)").astype("int")

train_df = train_df.rename(columns={"date_listed": "since_listing_month"})


# testing

test_df['date_listed'] = today.to_period('M') - test_df['date_listed'].dt.to_period('M')

test_df['date_listed'] = test_df['date_listed'].astype('str')
test_df['date_listed'] = test_df["date_listed"].str.extract("(\d+)").astype("int")

test_df = test_df.rename(columns={"date_listed": "since_listing_month"})

# %%
display(train_df)
# display(test_df)
# Out:
#                                name               street         type  \
# 0                          seascape         57 cove way   condominium
# 1                         la maison    10 moulmein rise     apartment
# 2                              viva      2 suffolk walk   condominium
# 3                   urban treasures     205 jalan eunos   condominium
# 5      the watergardens at canberra       canberra drive    apartment
# ...                             ...                  ...          ...
# 26040      the woodleigh residences  bidadari park drive    apartment
# 26041      the vermont on cairnhill  12b cairnhill rise     apartment
# 26042                   mon jervois     39 jervois road   condominium
# 26044                   dalvey haus     101 dalvey road   condominium
# 26046                     j gateway        gateway drive  condominium
#
#              model  bedrooms  bathrooms  district          region  \
# 0      condominium         3        4.0         4  central region
# 1        apartment         3        3.0        11  central region
# 2      condominium         4        3.0        11  central region
# 3      condominium         3        2.0        14     east region
# 5        apartment         2        1.0        27    north region
# ...            ...       ...        ...       ...             ...
# 26040    apartment         3        3.0        13  central region
# 26041    apartment         1        1.0         9  central region
# 26042  condominium         2        2.0        10  central region
# 26044  condominium         3        3.0        10  central region
# 26046  condominium         4        3.0        22     west region
#
#           planning_area           subszone       lat         lng  freehold  \
# 0      southern islands            sentosa  1.239337  103.837487         0
# 1                novena           moulmein  1.319533  103.847030         1
# 2                novena           moulmein  1.315656  103.844445         1
# 3                 bedok         kaki bukit  1.329367  103.905791         1
# 5             sembawang  sembawang springs  1.439199  103.829104         0
# ...                 ...                ...       ...         ...       ...
# 26040         toa payoh           bidadari  1.338214  103.872090         0
# 26041            newton          cairnhill  1.308991  103.838285         1
# 26042           tanglin         chatsworth  1.293516  103.822235         0
# 26044           tanglin             nassim  1.316263  103.825190         1
# 26046       jurong east     jurong gateway  1.335557  103.742417         0
#
#        since_built_year  no_of_units  area_size  since_listing_month  \
# 0                  11.0        151.0     2336.0                   11
# 1                  23.0         24.0     1259.0                   11
# 2                  10.0        235.0     1959.0                   10
# 3                  92.0        237.0      883.0                    3
# 5                  92.0        448.0      678.0                    3
# ...                 ...          ...        ...                  ...
# 26040              62.0        667.0      958.0                    4
# 26041               9.0        158.0      526.0                    3
# 26042               6.0        109.0      893.0                    7
# 26044              92.0         17.0     1561.0                    3
# 26046               6.0        738.0     1206.0                    6
#
#        additional_rooms      price
# 0                     0  5390000.0
# 1                     0  2310000.0
# 2                     0  5279500.0
# 3                     0  1843600.0
# 5                     0  1131900.0
# ...                 ...        ...
# 26040                 0  2090000.0
# 26041                 0  1650000.0
# 26042                 0  2090000.0
# 26044                 0  6449300.0
# 26046                 0  2420000.0
#
# [22417 rows x 19 columns]

# %% [markdown]
# ### remove outliers

# %%
temp_train_df = train_df.copy()
temp_test_df = test_df.copy()

# %%
# price < 700millions
temp_train_df = temp_train_df[temp_train_df['price'] < 70000000]
print(temp_train_df.shape)

# since built year < 200
temp_train_df = temp_train_df[temp_train_df['since_built_year'] < 200]
print(temp_train_df.shape)

# since list month < 18
temp_train_df = temp_train_df[temp_train_df['since_listing_month'] < 18]
print(temp_train_df.shape)

# bedroom < 9
temp_train_df = temp_train_df[temp_train_df['bedrooms'] < 9]
print(temp_train_df.shape)

# bathroom < 10
temp_train_df = temp_train_df[temp_train_df['bathrooms'] < 10]
print(temp_train_df.shape)
# Out:
# (22411, 19)
# (22407, 19)
# (22405, 19)
# (22404, 19)
# (22403, 19)

# %% [markdown]
# ### feature selection

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %% [markdown]
# #### remove street: too detailed

# %%
temp_train_df = temp_train_df.drop(columns=['street'])
temp_test_df = temp_test_df.drop(columns=['street'])

# %%
# temp_train_df

# %% [markdown]
# #### type vs. model: choose model

# %%
# type 
tukey = pairwise_tukeyhsd(endog=temp_train_df['price'],
                          groups=temp_train_df['type'],
                          alpha=0.05)

print(tukey)
# Out:
#          Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================================
#   group1     group2    meandiff  p-adj    lower       upper    reject
# ---------------------------------------------------------------------
# apartment condominium 83107.4391 0.128 -23911.5243 190126.4024  False
# ---------------------------------------------------------------------

# %%
# model
tukey = pairwise_tukeyhsd(endog=temp_train_df['price'],
                          groups=temp_train_df['model'],
                          alpha=0.05)

print(tukey)
# Out:
#                         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================================================
#         group1                group2           meandiff   p-adj      lower         upper     reject
# ---------------------------------------------------------------------------------------------------
#             apartment           condominium   173087.6794 0.0096    30863.7374   315311.6215   True
#             apartment executive condominium -1544547.5446  0.001 -1983777.2038 -1105317.8853   True
#             apartment                landed   -38679.6216    0.9 -1466193.9649  1388834.7216  False
#           condominium executive condominium  -1717635.224  0.001 -2158363.3966 -1276907.0515   True
#           condominium                landed  -211767.3011    0.9 -1639743.4314  1216208.8292  False
# executive condominium                landed  1505867.9229 0.0459    18652.1106  2993083.7353   True
# ---------------------------------------------------------------------------------------------------

# %%
temp_train_df = temp_train_df.drop(columns=['type'])
temp_test_df = temp_test_df.drop(columns=['type'])

# %% [markdown]
# #### freehold

# %%
# freehold
tukey = pairwise_tukeyhsd(endog=temp_train_df['price'],
                          groups=temp_train_df['freehold'],
                          alpha=0.05)

print(tukey)
# Out:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================================
# group1 group2   meandiff   p-adj    lower        upper     reject
# -----------------------------------------------------------------
#      0      1 1141806.8333 0.001 1033413.5224 1250200.1442   True
# -----------------------------------------------------------------

# %% [markdown]
# #### region

# %%
# region
tukey = pairwise_tukeyhsd(endog=temp_train_df['price'],
                          groups=temp_train_df['region'],
                          alpha=0.05)

print(tukey)

# change to binary: central area or not
# train
temp_train_df.loc[temp_train_df['region']=='central region', 'region'] = 1
temp_train_df.loc[temp_train_df['region']!=1, 'region'] = 0
temp_train_df = temp_train_df.astype({'region': 'int64'})
# test
temp_test_df.loc[temp_test_df['region']=='central region', 'region'] = 1
temp_test_df.loc[temp_test_df['region']!=1, 'region'] = 0
temp_test_df = temp_test_df.astype({'region': 'int64'})
# Out:
#                     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===========================================================================================
#       group1            group2         meandiff   p-adj      lower         upper     reject
# -------------------------------------------------------------------------------------------
#    central region       east region -2166820.1384  0.001 -2408834.3306 -1924805.9462   True
#    central region      north region -2309888.4487  0.001 -2711142.2867 -1908634.6106   True
#    central region north-east region -2120243.2946  0.001 -2356568.4878 -1883918.1014   True
#    central region       west region -2002024.1821  0.001 -2262106.8789 -1741941.4854   True
#       east region      north region  -143068.3103    0.9  -594731.9343   308595.3138  False
#       east region north-east region    46576.8438    0.9   -267819.377   360973.0647  False
#       east region       west region   164795.9563 0.6383  -167827.5485    497419.461  False
#      north region north-east region   189645.1541 0.7509  -258995.8572   638286.1653  False
#      north region       west region   307864.2665 0.3629  -153733.1438   769461.6768  False
# north-east region       west region   118219.1125 0.8482  -210288.3054   446726.5303  False
# -------------------------------------------------------------------------------------------

# %%
tukey = pairwise_tukeyhsd(endog=temp_train_df['price'],
                          groups=temp_train_df['region'],
                          alpha=0.05)
print(tukey)
# Out:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================================
# group1 group2   meandiff   p-adj    lower        upper     reject
# -----------------------------------------------------------------
#      0      1 2123065.1981 0.001 2012968.5138 2233161.8823   True
# -----------------------------------------------------------------

# %% [markdown]
# #### additional rooms

# %%
# additional
tukey = pairwise_tukeyhsd(endog=temp_train_df['price'],
                          groups=temp_train_df['additional_rooms'],
                          alpha=0.05)

print(tukey)



temp_train_df.loc[temp_train_df['additional_rooms']!=0, 'additional_rooms'] = 1
temp_test_df.loc[temp_test_df['additional_rooms']!=0, 'additional_rooms'] = 1
# display(temp_train_df)
# display(temp_test_df)

print(sum(temp_train_df['additional_rooms']))
print(sum(temp_test_df['additional_rooms']))
# Out:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================================
# group1 group2   meandiff  p-adj     lower        upper     reject
# -----------------------------------------------------------------
#      0      1 678873.4123 0.001   451099.3748  906647.4497   True
#      0      2 996037.8331 0.551 -1257956.5832 3250032.2494  False
#      1      2 317164.4208   0.9 -1946337.1909 2580666.0325  False
# -----------------------------------------------------------------
# 1945
# 548

# %%
tukey = pairwise_tukeyhsd(endog=temp_train_df['price'],
                          groups=temp_train_df['additional_rooms'],
                          alpha=0.05)

print(tukey)
# Out:
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================
# group1 group2  meandiff p-adj    lower       upper    reject
# ------------------------------------------------------------
#      0      1 681808.61 0.001 492142.0964 871475.1236   True
# ------------------------------------------------------------

# %% [markdown]
# #### name

# %%
train_df_groupby_name = train_df.groupby('name').count().sort_values(by='model', ascending=False)

top10_list_estate = list(train_df_groupby_name[:10].index)
top5_list_estate = list(train_df_groupby_name[:5].index)

# %%
top5_list_estate
# Out:
# ['marina one residences',
#  'normanton park',
#  'reflections at keppel bay',
#  'forett@bukit timah',
#  'canninghill piers']

# %%
temp_train_df.loc[~ temp_train_df['name'].isin(top5_list_estate), 'name'] = 'others'

# %%
tukey = pairwise_tukeyhsd(endog=temp_train_df['price'],
                          groups=temp_train_df['name'],
                          alpha=0.05)
print(tukey)
# Out:
#                           Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================================================================
#         group1                  group2             meandiff   p-adj      lower         upper     reject
# -------------------------------------------------------------------------------------------------------
#     canninghill piers        forett@bukit timah -2184157.1763  0.001 -3237413.0963 -1130901.2562   True
#     canninghill piers     marina one residences    944409.147 0.0569   -15436.0261  1904254.3201  False
#     canninghill piers            normanton park -2290336.7205  0.001 -3302580.5745 -1278092.8666   True
#     canninghill piers                    others -1270739.7847  0.001  -2085350.841  -456128.7283   True
#     canninghill piers reflections at keppel bay   1251074.743 0.0064   229951.0145  2272198.4715   True
#    forett@bukit timah     marina one residences  3128566.3232  0.001  2282184.0461  3974948.6003   True
#    forett@bukit timah            normanton park  -106179.5443    0.9 -1011551.1931   799192.1046  False
#    forett@bukit timah                    others   913417.3916 0.0017   236179.3419  1590655.4412   True
#    forett@bukit timah reflections at keppel bay  3435231.9193  0.001   2519942.964  4350520.8745   True
# marina one residences            normanton park -3234745.8675  0.001  -4029511.585   -2439980.15   True
# marina one residences                    others -2215148.9316  0.001 -2735347.0661 -1694950.7971   True
# marina one residences reflections at keppel bay   306665.5961 0.8827  -499379.4367  1112710.6288  False
#        normanton park                    others  1019596.9359  0.001   408089.8119  1631104.0598   True
#        normanton park reflections at keppel bay  3541411.4636  0.001  2673630.6973  4409192.2298   True
#                others reflections at keppel bay  2521814.5277  0.001  1895717.8805  3147911.1749   True
# -------------------------------------------------------------------------------------------------------

# %%
# train
temp_train_df.loc[temp_train_df['name'].isin(top5_list_estate), 'name'] = 1
temp_train_df.loc[temp_train_df['name'] != 1 , 'name'] = 0

# test
temp_test_df.loc[temp_test_df['name'].isin(top5_list_estate), 'name'] = 1
temp_test_df.loc[temp_test_df['name'] != 1 , 'name'] = 0

# %%
train_df = temp_train_df
test_df = temp_test_df

# %%
######################## finish feature selelction

# %%
display(train_df)
display(test_df)
# Out:
#       name        model  bedrooms  bathrooms  district  region  \
# 0        0  condominium         3        4.0         4       1
# 1        0    apartment         3        3.0        11       1
# 2        0  condominium         4        3.0        11       1
# 3        0  condominium         3        2.0        14       0
# 5        0    apartment         2        1.0        27       0
# ...    ...          ...       ...        ...       ...     ...
# 26040    0    apartment         3        3.0        13       1
# 26041    0    apartment         1        1.0         9       1
# 26042    0  condominium         2        2.0        10       1
# 26044    0  condominium         3        3.0        10       1
# 26046    0  condominium         4        3.0        22       0
#
#           planning_area           subszone       lat         lng  freehold  \
# 0      southern islands            sentosa  1.239337  103.837487         0
# 1                novena           moulmein  1.319533  103.847030         1
# 2                novena           moulmein  1.315656  103.844445         1
# 3                 bedok         kaki bukit  1.329367  103.905791         1
# 5             sembawang  sembawang springs  1.439199  103.829104         0
# ...                 ...                ...       ...         ...       ...
# 26040         toa payoh           bidadari  1.338214  103.872090         0
# 26041            newton          cairnhill  1.308991  103.838285         1
# 26042           tanglin         chatsworth  1.293516  103.822235         0
# 26044           tanglin             nassim  1.316263  103.825190         1
# 26046       jurong east     jurong gateway  1.335557  103.742417         0
#
#        since_built_year  no_of_units  area_size  since_listing_month  \
# 0                  11.0        151.0     2336.0                   11
# 1                  23.0         24.0     1259.0                   11
# 2                  10.0        235.0     1959.0                   10
# 3                  92.0        237.0      883.0                    3
# 5                  92.0        448.0      678.0                    3
# ...                 ...          ...        ...                  ...
# 26040              62.0        667.0      958.0                    4
# 26041               9.0        158.0      526.0                    3
# 26042               6.0        109.0      893.0                    7
# 26044              92.0         17.0     1561.0                    3
# 26046               6.0        738.0     1206.0                    6
#
#        additional_rooms      price
# 0                     0  5390000.0
# 1                     0  2310000.0
# 2                     0  5279500.0
# 3                     0  1843600.0
# 5                     0  1131900.0
# ...                 ...        ...
# 26040                 0  2090000.0
# 26041                 0  1650000.0
# 26042                 0  2090000.0
# 26044                 0  6449300.0
# 26046                 0  2420000.0
#
# [22403 rows x 17 columns]
#       name        model  bedrooms  bathrooms  district  region  \
# 26048    0  condominium         2        2.0        10       1
# 26049    0  condominium         3        2.0        15       1
# 26050    0    apartment         1        1.0        15       0
# 26051    0  condominium         2        1.0        17       0
# 26052    0  condominium         4        6.0         1       1
# ...    ...          ...       ...        ...       ...     ...
# 33543    0  condominium         1        1.0         3       1
# 33544    0  condominium         2        2.0        15       1
# 33545    0    apartment         3        2.0        23       0
# 33546    0  condominium         2        1.0        28       0
# 33547    0  condominium         3        5.0        10       1
#
#          planning_area        subszone       lat         lng  freehold  \
# 26048      bukit timah    farrer court  1.313566  103.803218         1
# 26049          kallang     tanjong rhu  1.298437  103.884408         1
# 26050            bedok         frankel  1.317851  103.908905         1
# 26051        pasir ris     flora drive  1.358005  103.965725         0
# 26052    downtown core           cecil  1.277474  103.849419         0
# ...                ...             ...       ...         ...       ...
# 33543  singapore river  robertson quay  1.289610  103.841276         0
# 33544          kallang     tanjong rhu  1.296610  103.867069         0
# 33545      bukit batok          gombak  1.375255  103.757531         0
# 33546         sengkang        fernvale  1.398588  103.874632         0
# 33547          tanglin      chatsworth  1.298781  103.826677         1
#
#        since_built_year  no_of_units  area_size  since_listing_month  \
# 26048              62.0        638.0      710.0                    4
# 26049               6.0        130.0     1055.0                    6
# 26050               9.0        157.0      463.0                    4
# 26051              92.0        428.0      645.0                    4
# 26052               5.0        510.0     6200.0                    9
# ...                 ...          ...        ...                  ...
# 33543              23.0        492.0      743.0                    4
# 33544              25.0        737.0     1345.0                    5
# 33545              92.0         74.0     1033.0                    3
# 33546               1.0        735.0      581.0                    4
# 33547               6.0        174.0     2067.0                    6
#
#        additional_rooms
# 26048                 0
# 26049                 0
# 26050                 0
# 26051                 0
# 26052                 0
# ...                 ...
# 33543                 0
# 33544                 0
# 33545                 1
# 33546                 1
# 33547                 0
#
# [7500 rows x 16 columns]

# %%
# output numeric only
num_cols = [
    "bedrooms",
    "bathrooms",
    "lat",
    "lng",
    "since_built_year",
    "no_of_units",
    "area_size",
    "since_listing_month",
]
bin_cols = ["name", "region", "additional_rooms", "freehold"]
cat_cols = ["model", "district", "planning_area", "subszone"]
res_col = ["price"]

assert len(num_cols + bin_cols + cat_cols + res_col) == train_df.shape[1]

train_numeric_df = train_df[num_cols + res_col]
test_numeric_df = test_df[num_cols]

display(train_numeric_df)


train_numeric_df.to_csv("./data_clean_output/train_numeric.csv")
test_numeric_df.to_csv("./data_clean_output/test_numeric.csv")
# Out:
#        bedrooms  bathrooms       lat         lng  since_built_year  \
# 0             3        4.0  1.239337  103.837487              11.0
# 1             3        3.0  1.319533  103.847030              23.0
# 2             4        3.0  1.315656  103.844445              10.0
# 3             3        2.0  1.329367  103.905791              92.0
# 5             2        1.0  1.439199  103.829104              92.0
# ...         ...        ...       ...         ...               ...
# 26040         3        3.0  1.338214  103.872090              62.0
# 26041         1        1.0  1.308991  103.838285               9.0
# 26042         2        2.0  1.293516  103.822235               6.0
# 26044         3        3.0  1.316263  103.825190              92.0
# 26046         4        3.0  1.335557  103.742417               6.0
#
#        no_of_units  area_size  since_listing_month      price
# 0            151.0     2336.0                   11  5390000.0
# 1             24.0     1259.0                   11  2310000.0
# 2            235.0     1959.0                   10  5279500.0
# 3            237.0      883.0                    3  1843600.0
# 5            448.0      678.0                    3  1131900.0
# ...            ...        ...                  ...        ...
# 26040        667.0      958.0                    4  2090000.0
# 26041        158.0      526.0                    3  1650000.0
# 26042        109.0      893.0                    7  2090000.0
# 26044         17.0     1561.0                    3  6449300.0
# 26046        738.0     1206.0                    6  2420000.0
#
# [22403 rows x 9 columns]

# %%
# output numeric + cat
train_df.to_csv('./data_clean_output/train_numeric_cat.csv')
test_df.to_csv('./data_clean_output/test_numeric_cat.csv')
